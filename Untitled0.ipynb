# %% [markdown]
# <a href="https://colab.research.google.com/github/arjunsai918/Intro_to_ML/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests
from io import StringIO
from matplotlib import markers

# %%
def load_data(url):
    response = requests.get(url)
    data = pd.read_csv(StringIO(response.text))
    return data

# %%
data = data.rename(columns={'X1': 'x1', 'X2': 'x2', 'X3': 'x3', 'Y': 'y'})

# Separate explanatory variables
x1 = data['x1']
x2 = data['x2']
x3 = data['x3']
y = data['y']
m=len(x1)
print(m)
# Out:
# 100

# %% [markdown]
# Gradient Descent function and Loss Function

# %%
def gradient_descent(X, Y, initial_theta, learning_rate, num_of_iterations):
    m = len(Y)
    theta = initial_theta
    losses = []

    for i in range(num_of_iterations):
        predictions = X.dot(theta)
        error = predictions - Y
        gradient = (X.T.dot(error) / m)
        theta -= learning_rate * gradient
        loss = np.sum(error**2) / (2 * m)
        losses.append(loss)

    return theta, losses

# %% [markdown]
# Problem 1 - Linear Regression for Each Explanatory Variable Individually

# %%
learning_rate = 0.07
num_iterations = 7777
initial_theta = np.zeros(2)
print(initial_theta)
# Out:
# [0. 0.]

# %%
theta1, cost_history1 = gradient_descent(np.column_stack((np.ones(len(x1)), x1)), y, initial_theta, learning_rate, num_iterations)
print('Final theta for X1 and Y:', theta1)
print('Final cost for X1 and Y =', cost_history1)
min(cost_history1)
# Out:
# Final theta for X1 and Y: [ 5.92794892 -2.03833663]
# Final cost for X1 and Y = [0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.9849930825405945, 0.98499308254 ...
# 0.9849930825405945

# %%
plt.scatter(x1, y, label='Actual Values', color='blue')
plt.plot(x1, np.column_stack((np.ones(len(x1)), x1)).dot(theta1), label='Linear Regression', color='red')
plt.grid(linestyle='-')
plt.xlabel('x1')
plt.ylabel('y')
plt.title('Linear Regression Model for x1 and y')
plt.legend()
plt.show()

# %%
theta2, cost_history2 = gradient_descent(np.column_stack((np.ones(len(x2)), x2)), y, initial_theta, learning_rate, num_iterations)
print('Final theta for X2 and Y:', theta2)
print('cost_history for X2 and Y =', cost_history2)
min(cost_history2)
# Out:
# Final theta for X2 and Y: [0.73606043 0.55760761]
# cost_history for X2 and Y = [8.18252582604345, 7.4734978092436135, 7.169528483568563, 6.999557895813714, 6.8753575515828205, 6.768164824404005, 6.668559718369362, 6.573415204959441, 6.481652915516445, 6.392862671414939, 6.306853444771391, 6.22350725749873, 6.142731609140128, 6.064443951681144, 5.988566588884038, 5.915024967650863, 5.843747074133106, 5.774663190629683, 5.70770577126433, 5.642809357687561, 5.579910509146304, 5.5189477385350605, 5.459861451660783, 5.402593888782259, 5.3470890680807, 5.293292730913196, 5.241152288765237, 5.190616771840621, 5.141636779235279, 5.094164430645263, 5.048153319561369, 5.003558467904502, 4.960336282057438, 4.918444510249953, 4.877842201255677, 4.838489664360305, 4.800348430561999, 4.763381214966099, 4.72755188033732, 4.692825401773885, 4.659167832468982, 4.626546
# 3.599366018168041

# %%
plt.scatter(x2, y, label='Actual Values', color='green')
plt.plot(x2, np.column_stack((np.ones(len(x2)), x2)).dot(theta2), label='Linear Regression', color='red')
plt.grid(linestyle='-')
plt.xlabel('x2')
plt.ylabel('y')
plt.title('Linear Regression Model for x2 and y')
plt.legend()
plt.show()

# %%
theta3, cost_history3 = gradient_descent(np.column_stack((np.ones(len(x3)), x3)), y, initial_theta, learning_rate, num_iterations)
print('Final theta for X3 and Y:', theta3)
print('cost_history for X3 and Y =', cost_history3)
print('min cost history3: ',min(cost_history3))
# Out:
# Final theta for X3 and Y: [ 2.8714221  -0.52048288]
# cost_history for X3 and Y = [4.407877431359307, 4.295236611568889, 4.244412563589908, 4.214997201340544, 4.193239692568138, 4.174452964900708, 4.157031964016124, 4.140419869606487, 4.124416604332497, 4.108943718316532, 4.0939644401520106, 4.079456484344217, 4.065402796081306, 4.051788394945976, 4.038599292544779, 4.025822115551284, 4.0134439688672, 4.001452380693759, 3.989835275714741, 3.9785809580916087, 3.967678098041043, 3.9571157198690874, 3.9468831907316972, 3.9369702098662254, 3.927366798199943, 3.9180632882969637, 3.909050314623803, 3.900318804120543, 3.8918599670669978, 3.883665288234287, 3.8757265183128116, 3.868035665607936, 3.8605849879950127, 3.8533669851256347, 3.8463743908773025, 3.8396001660388372, 3.833037491224266, 3.826679760007956, 3.820520572274151, 3.8145537277741948, 3.808773219884939, 3.8031732295620824, 3.797748119482331, 3.7924924283684915, 3.787400865491789, 3.7824683053458625, 3.777689782487095, 3.773060486536063, 3.768575757335086, 3.764231080257008, 3.760022081660466, 3.755944524487097, 3.75199430399623, 3.748167443632779, 3.7444600910241816, 3.740868514102343, 3.737389097346684, 3.7340183381445224, 3.7307528432651083, 3.727589325443768, 3.724524600072729, 3.7215555819952812, 3.7186792824000516, 3.715892805812265, 3.7131933471789718, 3.7105781890452905, 3.7080446988188402, 3.705590326119591, 3.703212600212493, 3.700909127520257, 3.698677589213828, 3.6965157388780967, 3.6944214002505062, 3.692392465030283, 3.6904268907560795, 3.688522698749896, 3.6866779721252163, 3.6848908538573335, 3.6831595449139543, 3.681482302444169, 3.6798574380239772, 3.6782833159566173, 3.6767583516259577, 3.67528100990132, 3.673849803592113, 3.6724632919507276, 3.671120079222187, 3.6698188132390794, 3.668558184060387, 3.6673369226528005, 3.6661537996132383, 3.6650076239312326, 3.663897241789993, 3.6628215354048894, 3.6617794218982187, 3.6607698522091043, 3.659791810037447, 3.658844310820847, 3.657926400743473, 3.6570371557759, 3.656175680744906, 3.65534110843234, 3.6545325987021147, 3.6537493376544807, 3.6529905368066924, 3.652255432299268, 3.651543284127044, 3.65085337539423, 3.6501850115927383, 3.649537519903045, 3.6489102485168847, 3.6483025659810915, 3.647713860561949, 3.647143539629364, 3.6465910290602968, 3.6460557726608, 3.64553723160613, 3.645034883898319, 3.6445482238406988, 3.644076761528839, 3.6436200223573705, 3.643177546542218, 3.6427488886577515, 3.64233361718839, 3.64193131409421, 3.641541574390116, 3.6411640057381622, 3.640798228052592, 3.6404438731172193, 3.6401005842147645, 3.6397680157677472, 3.6394458329906185, 3.6391337115527302, 3.6388313372518537, 3.6385384056978745, 3.6382546220063756, 3.637979700501792, 3.6377133644298225, 3.6374553456788346, 3.637205384509968, 3.6369632292956577, 3.636728636266335, 3.636501369265028, 3.6362811995096354, 3.636067905362615, 3.635861272107869, 3.635661091734602, 3.6354671627279105, 3.635279289865942, 3.6350972840233577, 3.6349209619809515, 3.6347501462412106, 3.634584664849634, 3.634424351221627, 3.6342690439748138, 3.6341185867665753, 3.633972828136661, 3.6338316213547275, 3.6336948242726193, 3.633562299181282, 3.633433912672129, 3.633309535502752, 3.633189042466802, 3.6330723122679656, 3.632959227397848, 3.6328496740176877, 3.6327435418437513, 3.632640724036325, 3.6325411170921535, 3.6324446207402534, 3.632351137840967, 3.6322605742881815, 3.6321728389145913, 3.6320878433999257, 3.6320055021820377, 3.6319257323707723, 3.631848453664523, 3.631773588269398, 3.6317010608209004, 3.631630798308073, 3.631562729999987, 3.6314967873745507, 3.631432904049525, 3.6313710157156978, 3.6313110600721514, 3.6312529767635384, 3.631196707319335, 3.6311421950949683, 3.6310893852148007, 3.631038224516893, 3.6309886614994746, 3.6309406462691127, 3.6308941304904767, 3.630849067337686, 3.63080541144717, 3.630763118871999, 3.6307221470376514, 3.6306824546991496, 3.6306440018995407, 3.6306067499296755, 3.630570661289239, 3.6305356996490037, 3.6305018298142504, 3.630469017689349, 3.630437230 ...
# min cost history3:  3.6294511246079137

# %%
plt.scatter(x3, y, label='Actual Values', color='orange')
plt.plot(x3, np.column_stack((np.ones(len(x3)), x3)).dot(theta3), label='Linear Regression', color='blue')
plt.grid(linestyle='-')
plt.xlabel('x3')
plt.ylabel('y')
plt.title('Linear Regression Model for x3 and y')
plt.legend()
plt.show()

# %% [markdown]
# Taking different learning rates for X1, X2 and X3 and plotting Loss Function
#
# First Learning rate was 0.07

# %%
theta1, cost_history1 = gradient_descent(np.column_stack((np.ones(len(x1)), x1)), y, initial_theta, learning_rate, num_iterations)
plt.plot(cost_history1)
plt.grid(linestyle='-')
plt.xlabel('Number of iterations')
plt.ylabel('Loss')
plt.title('Loss over Iterations for x1 and y')
plt.show()

# %%
theta2, cost_history2 = gradient_descent(np.column_stack((np.ones(len(x2)), x2)), y, initial_theta, learning_rate, num_iterations)
plt.plot(cost_history2)
plt.grid(linestyle='-')
plt.xlabel('Number of iterations')
plt.ylabel('Loss')
plt.title('Loss over Iterations for x2 and y')
plt.show()

# %%
theta3, cost_history1 = gradient_descent(np.column_stack((np.ones(len(x3)), x3)), y, initial_theta, learning_rate, num_iterations)
plt.plot(cost_history1)
plt.grid(linestyle='-')
plt.xlabel('Number of iterations')
plt.ylabel('Loss')
plt.title('Loss over Iterations for x3 and y')
plt.show()

# %% [markdown]
# Next taking learning rate as 0.06

# %%
learning_rate = 0.06
num_iterations = 6666
initial_theta = np.zeros(2)
print(initial_theta)
# Out:
# [0. 0.]

# %%
theta1, cost_history2 = gradient_descent(np.column_stack((np.ones(len(x1)), x1)), y, initial_theta, learning_rate, num_iterations)
plt.plot(cost_history2)
plt.grid(linestyle='-')
plt.xlabel('Number of iterations')
plt.ylabel('Loss')
plt.title('Loss over Iterations for x1 and y')
plt.show()

# %%
theta2, cost_history3 = gradient_descent(np.column_stack((np.ones(len(x2)), x2)), y, initial_theta, learning_rate, num_iterations)
plt.plot(cost_history3)
plt.grid(linestyle='-')
plt.xlabel('Number of iterations')
plt.ylabel('Loss')
plt.title('Loss over Iterations for x2 and y')
plt.show()

# %%
theta3, cost_history3 = gradient_descent(np.column_stack((np.ones(len(x3)), x3)), y, initial_theta, learning_rate, num_iterations)
plt.plot(cost_history3)
plt.grid(linestyle='-')
plt.xlabel('Number of iterations')
plt.ylabel('Loss')
plt.title('Loss over Iterations for x3 and y')
plt.show()

# %% [markdown]
# Next taking learning rate as 0.05

# %%
learning_rate = 0.05
num_iterations = 5555
initial_theta = np.zeros(2)
print(initial_theta)
# Out:
# [0. 0.]

# %%
theta1, cost_history1 = gradient_descent(np.column_stack((np.ones(len(x1)), x1)), y, initial_theta, learning_rate, num_iterations)
plt.plot(cost_history1)
plt.grid(linestyle='-')
plt.xlabel('Number of iterations')
plt.ylabel('Loss')
plt.title('Loss over Iterations for x1 and y')
plt.show()

# %%
theta2, cost_history2 = gradient_descent(np.column_stack((np.ones(len(x2)), x2)), y, initial_theta, learning_rate, num_iterations)
plt.plot(cost_history2)
plt.grid(linestyle='-')
plt.xlabel('Number of iterations')
plt.ylabel('Loss')
plt.title('Loss over Iterations for x2 and y')
plt.show()

# %%
theta3, cost_history3 = gradient_descent(np.column_stack((np.ones(len(x3)), x3)), y, initial_theta, learning_rate, num_iterations)
plt.plot(cost_history3)
plt.grid(linestyle='-')
plt.xlabel('Number of iterations')
plt.ylabel('Loss')
plt.title('Loss over Iterations for x3 and y')
plt.show()

# %% [markdown]
# Next taking learning rate very high 0.3

# %%
learning_rate = 0.3
num_iterations = 2000
initial_theta = np.zeros(2)
print(initial_theta)
# Out:
# [0. 0.]

# %%
theta1, cost_history1 = gradient_descent(np.column_stack((np.ones(len(x1)), x1)), y, initial_theta, learning_rate, num_iterations)
plt.plot(cost_history1)
plt.grid(linestyle='-')
plt.xlabel('Number of iterations')
plt.ylabel('Loss')
plt.title('Loss over Iterations for x1 and y')
plt.show()

# %%
theta2, cost_history2 = gradient_descent(np.column_stack((np.ones(len(x2)), x2)), y, initial_theta, learning_rate, num_iterations)
plt.plot(cost_history2)
plt.grid(linestyle='-')
plt.xlabel('Number of iterations')
plt.ylabel('Loss')
plt.title('Loss over Iterations for x2 and y')
plt.show()

# %%
theta3, cost_history3 = gradient_descent(np.column_stack((np.ones(len(x3)), x3)), y, initial_theta, learning_rate, num_iterations)
plt.plot(cost_history3)
plt.grid(linestyle='-')
plt.xlabel('Number of iterations')
plt.ylabel('Loss')
plt.title('Loss over Iterations for x3 and y')
plt.show()

# %% [markdown]
# Problem 2 - Linear Regression with All Explanatory Variables

# %%
learning_rate = 0.03
num_iterations = 4000
initial_theta = np.zeros(4)

X = np.column_stack((np.ones(len(x1)), x1, x2, x3))
theta4, cost_history4 = gradient_descent(X, y, initial_theta, learning_rate, num_iterations)
print('Final theta for X1, X2, X3, and Y:', theta4)
plt.plot(cost_history4)
plt.grid(linestyle='-')
plt.xlabel('Number of iterations')
plt.ylabel('Loss')
plt.title('Loss over Iterations for X1, X2, X3, and Y')
plt.show()

# Predict values for new inputs
test_data = np.array([[1, 1, 1, 1], [1, 2, 0, 4], [1, 3, 2, 1]])
predictions = test_data.dot(theta4)
print("values predicted for the new inputs:", predictions)
# Out:
# Final theta for X1, X2, X3, and Y: [ 5.31413463 -2.00371467  0.53256871 -0.2655971 ]
# values predicted for the new inputs: [3.57739158 0.2443169  0.10253095]

# %%
learning_rate = 0.01
num_iterations = 1000
initial_theta = np.zeros(4)

# %%
theta4, cost_history4 = gradient_descent(X, y, initial_theta, learning_rate, num_iterations)
plt.plot(cost_history4)
plt.grid(linestyle='-')
plt.xlabel('Number of iterations')
plt.ylabel('Loss')
plt.title('Loss over Iterations for X1, X2, X3, and Y')
plt.show()

# %%
learning_rate = 0.2
num_iterations = 5000
initial_theta = np.zeros(4)

# %%
theta4, cost_history4 = gradient_descent(X, y, initial_theta, learning_rate, num_iterations)
plt.plot(cost_history4)
plt.grid(linestyle='-')
plt.xlabel('Number of iterations')
plt.ylabel('Loss')
plt.title('Loss over Iterations')
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/numpy/core/_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)

# %%
learning_rate = 0.8
num_iterations = 300
initial_theta = np.zeros(4)

# %%
theta4, cost_history4 = gradient_descent(X, y, initial_theta, learning_rate, num_iterations)
plt.plot(cost_history4)
plt.grid(linestyle='-')
plt.xlabel('Number of iterations')
plt.ylabel('Loss')
plt.title('Loss over Iterations')
plt.show()
